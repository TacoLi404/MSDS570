# %% [markdown]
# ## Import the data

# %%
# import dataset (2015-2020, Country, Drinking Water, Analyze by Service Level)
# downloaded data will show drinking water broken down by country, service level and residence type (rural, urban, and total)
import pandas as pd
world_dw = pd.read_csv('drinkingwater1520.csv', header=0)
header_names = world_dw.columns.tolist()
print(header_names)
# Out:
# ['ISO3', 'Country', 'Residence Type', 'Service Type', 'Year', 'Coverage', 'Population', 'Service level']

# %%
world_dw.head(5)
# Out:
#   ISO3 Country Residence Type    Service Type  Year  Coverage    Population  \
# 0  ABW   Aruba          total  Drinking water  2015  97.86903  1.021156e+05
# 1  ABW   Aruba          total  Drinking water  2016  97.86903  1.026304e+05
# 2  AGO  Angola          total  Drinking water  2015  54.31693  1.514594e+07
# 3  AGO  Angola          rural  Drinking water  2015  26.71437  2.722957e+06
# 4  AGO  Angola          urban  Drinking water  2015  70.21996  1.242298e+07
#
#     Service level
# 0  At least basic
# 1  At least basic
# 2  At least basic
# 3  At least basic
# 4  At least basic

# %% [markdown]
# ## Analyze the data

# %%
# import libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# get dataset info
world_dw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15107 entries, 0 to 15106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISO3            15107 non-null  object
#  1   Country         15107 non-null  object
#  2   Residence Type  15107 non-null  object
#  3   Service Type    15107 non-null  object
#  4   Year            15107 non-null  int64
#  5   Coverage        15107 non-null  float64
#  6   Population      15107 non-null  float64
#  7   Service level   15107 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 944.3+ KB

# %%
# get Service level info
service_levels = world_dw['Service level'].unique()
print(service_levels)
# Out:
# ['At least basic' 'Basic service' 'Limited service'
#  'Safely managed service' 'Surface water' 'Unimproved']

# %%
# replace Service level info with numeric
world_dw['Service level'] = world_dw['Service level'].replace({'Surface water': 0, 'Unimproved': 1, 
                                                                   'Limited service': 2, 'Basic service' : 3,
                                                                  'At least basic' : 4, 'Safely managed service' : 5})
world_dw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15107 entries, 0 to 15106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISO3            15107 non-null  object
#  1   Country         15107 non-null  object
#  2   Residence Type  15107 non-null  object
#  3   Service Type    15107 non-null  object
#  4   Year            15107 non-null  int64
#  5   Coverage        15107 non-null  float64
#  6   Population      15107 non-null  float64
#  7   Service level   15107 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 944.3+ KB

# %%
# create new dataset with Residence Type equal to "total"
total_dw = world_dw.loc[world_dw["Residence Type"] == "total"]
total_dw.head()
# Out:
#   ISO3 Country Residence Type    Service Type  Year  Coverage    Population  \
# 0  ABW   Aruba          total  Drinking water  2015  97.86903  1.021156e+05
# 1  ABW   Aruba          total  Drinking water  2016  97.86903  1.026304e+05
# 2  AGO  Angola          total  Drinking water  2015  54.31693  1.514594e+07
# 5  AGO  Angola          total  Drinking water  2016  55.08428  1.588767e+07
# 8  AGO  Angola          total  Drinking water  2017  55.84291  1.665055e+07
#
#    Service level
# 0              4
# 1              4
# 2              4
# 5              4
# 8              4

# %%
# Sort the dataset by the 'Year', 'Population' and 'Service level' columns
sorted_dw = total_dw.sort_values(['Year', 'Population', 'Service level'])

# Show the first twenty rows of the sorted dataset
print(sorted_dw.head(20))
# Out:
#      ISO3                 Country Residence Type    Service Type  Year  \
# 8496  AIA                Anguilla          total  Drinking water  2015
# 8502  ALB                 Albania          total  Drinking water  2015
# 8520  AND                 Andorra          total  Drinking water  2015
# 8538  ARE    United Arab Emirates          total  Drinking water  2015
# 8572  ASM          American Samoa          total  Drinking water  2015
# 8581  AUS               Australia          total  Drinking water  2015
# 8599  AUT                 Austria          total  Drinking water  2015
# 8653  BEL                 Belgium          total  Drinking water  2015
# 8725  BGR                Bulgaria          total  Drinking water  2015
# 8743  BHR                 Bahrain          total  Drinking water  2015
# 8749  BHS                 Bahamas          total  Drinking water  2015
# 8754  BIH  Bosnia and Herzegovina          total  Drinking water  2015
# 8772  BLM        Saint Barthélemy          total  Drinking water  2015
# 8784  BLR                 Belarus          total  Drinking water  2015
# 8820  BMU                 Bermuda          total  Drinking water  2015
# 8860  BRB                Barbados          total  Drinking water  2015
# 8933  CAN                  Canada          total  Drinking water  2015
# 8951  CHE             Switzerland          total  Drinking water  2015
# 8969  CHI         Channel Islands          total  Drinking water  2015
# 8972  CHL                   Chile          total  Drinking water  2015
#
#       Coverage  Population  Service level
# 8496       0.0         0.0              0
# 8502       0.0         0.0              0
# 8520       0.0         0.0              0
# 8538       0.0         0.0              0
# 8572       0.0         0.0              0
# 8581       0.0         0.0              0
# 8599       0.0         0.0              0
# 8653       0.0         0.0              0
# 8725       0.0         0.0              0
# 8743       0.0         0.0              0
# 8749       0.0         0.0              0
# 8754       0.0         0.0              0
# 8772       0.0         0.0              0
# 8784       0.0         0.0              0
# 8820       0.0         0.0              0
# 8860       0.0         0.0              0
# 8933       0.0         0.0              0
# 8951       0.0         0.0              0
# 8969       0.0         0.0              0
# 8972       0.0         0.0              0

# %%
# Drop rows where population is 0
sorted_dw = sorted_dw.drop(sorted_dw[sorted_dw['Population'] == 0.0].index)

# Show the first twenty rows of the sorted dataset
print(sorted_dw.head(20))
# Out:
#       ISO3                                     Country Residence Type  \
# 11810  AND                                     Andorra          total
# 14020  NZL                                 New Zealand          total
# 12535  DNK                                     Denmark          total
# 12680  FIN                                     Finland          total
# 11943  BEL                                     Belgium          total
# 14713  TKL                                     Tokelau          total
# 12378  COK                                Cook Islands          total
# 13774  MNP                    Northern Mariana Islands          total
# 2735   NIU                                        Niue          total
# 13966  NIU                                        Niue          total
# 14957  VGB                      British Virgin Islands          total
# 14386  SHN                                Saint Helena          total
# 12110  BMU                                     Bermuda          total
# 14128  PLW                                       Palau          total
# 15005  WLF                   Wallis and Futuna Islands          total
# 8578   ATG                         Antigua and Barbuda          total
# 13816  MSR                                  Montserrat          total
# 8802   BLZ                                      Belize          total
# 2513   MAC  China, Macao Special Administrative Region          total
# 12716  FLK                 Falkland Islands (Malvinas)          total
#
#          Service Type  Year  Coverage  Population  Service level
# 11810  Drinking water  2015   0.00000     0.00191              1
# 14020  Drinking water  2015   0.00000     0.12228              1
# 12535  Drinking water  2015   0.00000     0.12231              1
# 12680  Drinking water  2015   0.00000     0.18307              1
# 11943  Drinking water  2015   0.00000     0.25962              1
# 14713  Drinking water  2015   0.54260     6.76627              1
# 12378  Drinking water  2015   0.04633     8.14510              1
# 13774  Drinking water  2015   0.01982    11.05351              1
# 2735   Drinking water  2015   2.28572    36.80016              3
# 13966  Drinking water  2015   2.39386    38.54116              1
# 14957  Drinking water  2015   0.13562    39.52948              1
# 14386  Drinking water  2015   1.05000    61.62450              1
# 12110  Drinking water  2015   0.09686    61.69497              1
# 14128  Drinking water  2015   0.36985    65.33385              1
# 15005  Drinking water  2015   0.67862    83.21220              1
# 8578   Drinking water  2015   0.09447    88.39289              0
# 13816  Drinking water  2015   1.92918    95.80305              1
# 8802   Drinking water  2015   0.02824   101.93268              0
# 2513   Drinking water  2015   0.02042   122.92732              3
# 12716  Drinking water  2015   5.17999   146.90461              1

# %%
# Sort the dataset by the 'Year', 'Population' and 'Service level' columns
sorted_dw = sorted_dw.sort_values(['Year', 'Service level', 'Population'], ascending=[True, True, False])

# Show the first five rows of the sorted dataset
print(sorted_dw.head(5))
# Out:
#       ISO3   Country Residence Type    Service Type  Year  Coverage  \
# 10607  NGA   Nigeria          total  Drinking water  2015   9.77293
# 9362   ETH  Ethiopia          total  Drinking water  2015  11.71329
# 9965   KEN     Kenya          total  Drinking water  2015  21.48340
# 9791   IND     India          total  Drinking water  2015   0.75682
# 8990   CHN     China          total  Drinking water  2015   0.63652
#
#          Population  Service level
# 10607  1.770244e+07              0
# 9362   1.181115e+07              0
# 9965   1.028590e+07              0
# 9791   9.915453e+06              0
# 8990   9.104798e+06              0

# %% [markdown]
# ### Based on this filter, we will want to make a future consideration to look more closely at the following countries' change in Service Level over time: Nigeria, Ethiopia, Kenya, India, China, because these are the countries with the lowest service level of drinking water and the highest population.

# %% [markdown]
# # Looking at drinking water service levels around the world by year

# %%
# rename ISO3 to CODE
total_dw = total_dw.rename(columns={'ISO3': 'CODE'})

total_dw.head()
# Out:
#   CODE Country Residence Type    Service Type  Year  Coverage    Population  \
# 0  ABW   Aruba          total  Drinking water  2015  97.86903  1.021156e+05
# 1  ABW   Aruba          total  Drinking water  2016  97.86903  1.026304e+05
# 2  AGO  Angola          total  Drinking water  2015  54.31693  1.514594e+07
# 5  AGO  Angola          total  Drinking water  2016  55.08428  1.588767e+07
# 8  AGO  Angola          total  Drinking water  2017  55.84291  1.665055e+07
#
#    Service level
# 0              4
# 1              4
# 2              4
# 5              4
# 8              4

# %%
import geopandas as gpd
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
# read countries data file 
world = gpd.read_file('ne_10m_admin_0_countries.shp')
world.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          0          2  Indonesia    IDN         0      2
# 1  Admin-0 country          0          3   Malaysia    MYS         0      2
# 2  Admin-0 country          0          2      Chile    CHL         0      2
# 3  Admin-0 country          0          3    Bolivia    BOL         0      2
# 4  Admin-0 country          0          2       Peru    PER         0      2
#
#                 TYPE TLC      ADMIN  ... FCLASS_TR  FCLASS_ID FCLASS_PL  \
# 0  Sovereign country   1  Indonesia  ...       NaN        NaN       NaN
# 1  Sovereign country   1   Malaysia  ...       NaN        NaN       NaN
# 2  Sovereign country   1      Chile  ...       NaN        NaN       NaN
# 3  Sovereign country   1    Bolivia  ...       NaN        NaN       NaN
# 4  Sovereign country   1       Peru  ...       NaN        NaN       NaN
#
#   FCLASS_GR  FCLASS_IT FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0       NaN        NaN       NaN       NaN        NaN       NaN
# 1       NaN        NaN       NaN       NaN        NaN       NaN
# 2       NaN        NaN       NaN       NaN        NaN       NaN
# 3       NaN        NaN       NaN       NaN        NaN       NaN
# 4       NaN        NaN       NaN       NaN        NaN       NaN
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
#
# [5 rows x 169 columns]

# %%
# select needed columns
world = world[['SOV_A3', 'geometry']]
world.head()
# Out:
#   SOV_A3                                           geometry
# 0    IDN  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1    MYS  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2    CHL  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    BOL  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4    PER  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...

# %%
# rename the columns so that we can merge with our data
world.rename(columns = {'SOV_A3':'CODE'}, inplace = True)
world.head()
# Out:
#   CODE                                           geometry
# 0  IDN  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MYS  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  CHL  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3  BOL  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4  PER  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...

# %%
# then merge with our data 
totalworld=pd.merge(total_dw, world,on='CODE')
totalworld.head()
#totalworld.tail()
# Out:
#   CODE Country Residence Type    Service Type  Year  Coverage    Population  \
# 0  AGO  Angola          total  Drinking water  2015  54.31693  1.514594e+07
# 1  AGO  Angola          total  Drinking water  2016  55.08428  1.588767e+07
# 2  AGO  Angola          total  Drinking water  2017  55.84291  1.665055e+07
# 3  AGO  Angola          total  Drinking water  2018  56.59175  1.743580e+07
# 4  AGO  Angola          total  Drinking water  2019  56.88304  1.810320e+07
#
#    Service level                                           geometry
# 0              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 1              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 2              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 3              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 4              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...

# %%
# read latitude longitude countries csv
location=pd.read_csv('countries_latitude_longitude.csv')
location.head()
# Out:
#           name   latitude  longitude
# 0  Afghanistan  33.939110  67.709953
# 1      Albania  41.153332  20.168331
# 2      Algeria  28.033886   1.659626
# 3       Angola -11.202692  17.873887
# 4    Argentina -38.416097 -63.616672

# %%
# rename name column to Country
location.rename(columns = {'name':'Country'}, inplace = True)
location.head()
# Out:
#        Country   latitude  longitude
# 0  Afghanistan  33.939110  67.709953
# 1      Albania  41.153332  20.168331
# 2      Algeria  28.033886   1.659626
# 3       Angola -11.202692  17.873887
# 4    Argentina -38.416097 -63.616672

# %%
# merge totalworld with location on Country
totalworldnew=pd.merge(totalworld, location, on='Country')
totalworldnew
# Out:
#      CODE   Country Residence Type    Service Type  Year  Coverage  \
# 0     AGO    Angola          total  Drinking water  2015  54.31693
# 1     AGO    Angola          total  Drinking water  2016  55.08428
# 2     AGO    Angola          total  Drinking water  2017  55.84291
# 3     AGO    Angola          total  Drinking water  2018  56.59175
# 4     AGO    Angola          total  Drinking water  2019  56.88304
# ...   ...       ...            ...             ...   ...       ...
# 3416  ZWE  Zimbabwe          total  Drinking water  2016  15.98693
# 3417  ZWE  Zimbabwe          total  Drinking water  2017  16.06900
# 3418  ZWE  Zimbabwe          total  Drinking water  2018  16.14477
# 3419  ZWE  Zimbabwe          total  Drinking water  2019  16.21455
# 3420  ZWE  Zimbabwe          total  Drinking water  2020  16.27786
#
#         Population  Service level  \
# 0     1.514594e+07              4
# 1     1.588767e+07              4
# 2     1.665055e+07              4
# 3     1.743580e+07              4
# 4     1.810320e+07              4
# ...            ...            ...
# 3416  2.243020e+06              1
# 3417  2.287680e+06              1
# 3418  2.331113e+06              1
# 3419  2.374697e+06              1
# 3420  2.419366e+06              1
#
#                                                geometry   latitude  longitude
# 0     MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4... -11.202692  17.873887
# 1     MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4... -11.202692  17.873887
# 2     MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4... -11.202692  17.873887
# 3     MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4... -11.202692  17.873887
# 4     MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4... -11.202692  17.873887
# ...                                                 ...        ...        ...
# 3416  POLYGON ((25.25978 -17.79411, 25.26671 -17.800... -19.015438  29.154857
# 3417  POLYGON ((25.25978 -17.79411, 25.26671 -17.800... -19.015438  29.154857
# 3418  POLYGON ((25.25978 -17.79411, 25.26671 -17.800... -19.015438  29.154857
# 3419  POLYGON ((25.25978 -17.79411, 25.26671 -17.800... -19.015438  29.154857
# 3420  POLYGON ((25.25978 -17.79411, 25.26671 -17.800... -19.015438  29.154857
#
# [3421 rows x 11 columns]

# %%
#totalwaternew.to_csv('totalwater.csv', index=False)

# %%
totalworld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4784 entries, 0 to 4783
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODE            4784 non-null   object
#  1   Country         4784 non-null   object
#  2   Residence Type  4784 non-null   object
#  3   Service Type    4784 non-null   object
#  4   Year            4784 non-null   int64
#  5   Coverage        4784 non-null   float64
#  6   Population      4784 non-null   float64
#  7   Service level   4784 non-null   int64
#  8   geometry        4784 non-null   geometry
# dtypes: float64(2), geometry(1), int64(2), object(4)
# memory usage: 373.8+ KB

# %%
# create dataset for 2015
#year = '2015'
#totalworld2015 = totalworld.loc[totalworld['Year'] == year]
#print(totalworld2015.head(5))

# %%
# set column names
#totalwater.columns = ['CODE', 'Country', 'Residence Type', 'Service Type', 'Year', 'Coverage', 'Population', 'Service level']
#totalwater.info()
#totalwater.head()

# %%
#totalwater15 = totalwater[totalwater['Year'] == '2015']
#print(totalwater15)

#totalwater.head()

# %% [markdown]
# ## Building the map

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in ./opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: fiona>=1.8 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: shapely>=1.7 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in ./.local/lib/python3.9/site-packages (from geopandas) (23.0)
# Requirement already satisfied: pyproj>=2.6.1.post1 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: pandas>=1.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: click~=8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: importlib-metadata in ./.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (6.0.0)
# Requirement already satisfied: certifi in ./.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: munch>=2.3.2 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in ./.local/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: six in ./.local/lib/python3.9/site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in ./.local/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)

# %%
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in ./opt/anaconda3/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (from folium) (1.22.4)
# Requirement already satisfied: branca>=0.6.0 in ./opt/anaconda3/lib/python3.9/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in ./opt/anaconda3/lib/python3.9/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in ./.local/lib/python3.9/site-packages (from folium) (2.28.2)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.9/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.local/lib/python3.9/site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.9/site-packages (from requests->folium) (3.1.0)

# %%
totalworldnew.head()
# Out:
#   CODE Country Residence Type    Service Type  Year  Coverage    Population  \
# 0  AGO  Angola          total  Drinking water  2015  54.31693  1.514594e+07
# 1  AGO  Angola          total  Drinking water  2016  55.08428  1.588767e+07
# 2  AGO  Angola          total  Drinking water  2017  55.84291  1.665055e+07
# 3  AGO  Angola          total  Drinking water  2018  56.59175  1.743580e+07
# 4  AGO  Angola          total  Drinking water  2019  56.88304  1.810320e+07
#
#    Service level                                           geometry  \
# 0              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 1              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 2              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 3              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
# 4              4  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...
#
#     latitude  longitude
# 0 -11.202692  17.873887
# 1 -11.202692  17.873887
# 2 -11.202692  17.873887
# 3 -11.202692  17.873887
# 4 -11.202692  17.873887

# %% [markdown]
# ## Create 2015 drinking water service level dataset

# %%
import pandas as pd
dw2015 = pd.read_csv('drinkingwater2015.csv', header=0)
dw2015.head()
# Out:
#   ISO3      Country Residence Type    Service Type  Year  Coverage  \
# 0  ABW        Aruba          total  Drinking water  2015  97.86903
# 1  ABW        Aruba          total  Drinking water  2015   0.00000
# 2  ABW        Aruba          total  Drinking water  2015   0.17104
# 3  ABW        Aruba          total  Drinking water  2015   1.95994
# 4  AFG  Afghanistan          total  Drinking water  2015  37.96357
#
#      Population    Service level
# 0  1.021156e+05   At least basic
# 1  0.000000e+00  Limited service
# 2  1.784618e+02    Surface water
# 3  2.044978e+03       Unimproved
# 4  1.306463e+07    Basic service

# %%
# replace Service level info with numeric
dw2015['Service level'] = dw2015['Service level'].replace({'Surface water': 0, 'Unimproved': 1, 
                                                                   'Limited service': 2, 'Basic service' : 3,
                                                                  'At least basic' : 4, 'Safely managed service' : 5})
dw2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISO3            1056 non-null   object
#  1   Country         1056 non-null   object
#  2   Residence Type  1056 non-null   object
#  3   Service Type    1056 non-null   object
#  4   Year            1056 non-null   int64
#  5   Coverage        1056 non-null   float64
#  6   Population      1056 non-null   float64
#  7   Service level   1056 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 66.1+ KB

# %%
# rename ISO3 to CODE
dw2015 = dw2015.rename(columns={'ISO3': 'CODE'})

dw2015.head()
# Out:
#   CODE      Country Residence Type    Service Type  Year  Coverage  \
# 0  ABW        Aruba          total  Drinking water  2015  97.86903
# 1  ABW        Aruba          total  Drinking water  2015   0.00000
# 2  ABW        Aruba          total  Drinking water  2015   0.17104
# 3  ABW        Aruba          total  Drinking water  2015   1.95994
# 4  AFG  Afghanistan          total  Drinking water  2015  37.96357
#
#      Population  Service level
# 0  1.021156e+05              4
# 1  0.000000e+00              2
# 2  1.784618e+02              0
# 3  2.044978e+03              1
# 4  1.306463e+07              3

# %%
# merge dw2015 with location on Country
dw2015new=pd.merge(dw2015, location, on='Country')
dw2015new
# Out:
#     CODE      Country Residence Type    Service Type  Year  Coverage  \
# 0    AFG  Afghanistan          total  Drinking water  2015  37.96357
# 1    AFG  Afghanistan          total  Drinking water  2015   3.51120
# 2    AFG  Afghanistan          total  Drinking water  2015  23.37621
# 3    AFG  Afghanistan          total  Drinking water  2015  12.98024
# 4    AFG  Afghanistan          total  Drinking water  2015  22.16878
# ..   ...          ...            ...             ...   ...       ...
# 619  ZWE     Zimbabwe          total  Drinking water  2015  34.56975
# 620  ZWE     Zimbabwe          total  Drinking water  2015  12.45676
# 621  ZWE     Zimbabwe          total  Drinking water  2015  30.38518
# 622  ZWE     Zimbabwe          total  Drinking water  2015   6.68946
# 623  ZWE     Zimbabwe          total  Drinking water  2015  15.89884
#
#        Population  Service level   latitude  longitude
# 0    1.306463e+07              3  33.939110  67.709953
# 1    1.208330e+06              2  33.939110  67.709953
# 2    8.044594e+06              5  33.939110  67.709953
# 3    4.466966e+06              0  33.939110  67.709953
# 4    7.629077e+06              1  33.939110  67.709953
# ..            ...            ...        ...        ...
# 619  4.775687e+06              3 -19.015438  29.154857
# 620  1.720857e+06              2 -19.015438  29.154857
# 621  4.197604e+06              5 -19.015438  29.154857
# 622  9.241255e+05              0 -19.015438  29.154857
# 623  2.196368e+06              1 -19.015438  29.154857
#
# [624 rows x 10 columns]

# %%
import pandas as pd
import folium

# read the dataset
dw2015new.head()

# Create a world map centered on the equator
map = folium.Map(location=[0, 0], zoom_start=2, name="Drinking Water Service Levels - 2015")

# Add markers to the map for each country in the dataset
for index, row in dw2015new.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    service_level = row['Service level']

    # Add marker for each country, colored by service level
    if service_level == '4':
        color = 'green'
    elif service_level == '3':
        color = 'yellow'
    elif service_level == '2':
        color = 'orange'
    elif service_level == '1':
        color = 'red'
    else:
        color = 'blue'
        
    folium.Marker(location=[lat, lon], icon=folium.Icon(color=color)).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c24f72abcb9274ee8e4101a368774cfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c24f72abcb9274ee8e4101a368774cfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c24f72abcb9274ee8e4101a368774cfb = L.map(
#                 &quot;map_c24f72abcb9274ee8e4101a368774cfb&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Drinking Water Service Levels - 2015&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_892e243bee03b8452e422e472bd6782a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var marker_e17e7dea442bac734adf155ebb2566d8 = L.marker(
#                 [33.93911, 67.709953],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_efd2b70d6d48c85bc412e8eafa6bf51a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e17e7dea442bac734adf155ebb2566d8.setIcon(icon_efd2b70d6d48c85bc412e8eafa6bf51a);
#
#
#             var marker_bb2164c28610db356b66a684d0839b29 = L.marker(
#                 [33.93911, 67.709953],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_077c7e55d13a90ce347a6ddb8d3fd71f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bb2164c28610db356b66a684d0839b29.setIcon(icon_077c7e55d13a90ce347a6ddb8d3fd71f);
#
#
#             var marker_c0a7627f33382b4faf77dbfff325cabb = L.marker(
#                 [33.93911, 67.709953],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_63a877203210910f168bb294a0714891 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0a7627f33382b4faf77dbfff325cabb.setIcon(icon_63a877203210910f168bb294a0714891);
#
#
#             var marker_a52b08b901decf3e5b3a7b33a8b7ca30 = L.marker(
#                 [33.93911, 67.709953],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_bd87346547642c62ce11ba42a3085b93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a52b08b901decf3e5b3a7b33a8b7ca30.setIcon(icon_bd87346547642c62ce11ba42a3085b93);
#
#
#             var marker_27add99c3bb54b8739537c562e816c22 = L.marker(
#                 [33.93911, 67.709953],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_3fbde4e7a3cd70d87096df59cf9b0928 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27add99c3bb54b8739537c562e816c22.setIcon(icon_3fbde4e7a3cd70d87096df59cf9b0928);
#
#
#             var marker_ca1724994c0df863a275b49c0f5d8205 = L.marker(
#                 [-11.202692, 17.873887],
#                 {}
#             ).addTo(map_c24f72abcb9274ee8e4101a368774cfb);
#
#
#             var icon_deed81b949a4edfabdcf3ac6a148ed9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca1724994c0df863a275b49c0f5d8205.setIcon(icon_deed81b949a4edfabdcf3ac6a148ed9c);
#
#
#             var marker_c067dfa705661dd453a722a08c1df2ec = L.marker(
#                 [-11.202692, 17.873887],
#                 {}
#             ).addTo(map_c24

# %% [markdown]
# ## Rural and urban drinking water service levels, 2015 and 2020

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load data
dw_15v20 = pd.read_csv('2015v2020dw.csv')
dw_15v20.head()
# Out:
#    Year    Service Type           Service Level   Coverage   Type Region  \
# 0  2015  Drinking water           Basic service  26.161708  world  World
# 1  2015  Drinking water           Basic service  11.075658  world  World
# 2  2015  Drinking water         Limited service   5.392324  world  World
# 3  2015  Drinking water         Limited service   1.640053  world  World
# 4  2015  Drinking water  Safely managed service  52.836610  world  World
#
#   Residence Type    Population
# 0          rural  8.893554e+08
# 1          urban  4.408441e+08
# 2          rural  1.833096e+08
# 3          urban  6.527899e+07
# 4          rural  1.796157e+09

# %%
dw_15v20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Service Type    20 non-null     object
#  2   Service Level   20 non-null     object
#  3   Coverage        20 non-null     float64
#  4   Type            20 non-null     object
#  5   Region          20 non-null     object
#  6   Residence Type  20 non-null     object
#  7   Population      20 non-null     float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.4+ KB

# %%
# replace Service level info with numeric
dw_15v20['Service Level'] = dw_15v20['Service Level'].replace({'Surface water': 0, 'Unimproved': 1, 
                                                                   'Limited service': 2, 'Basic service' : 3,
                                                                  'At least basic' : 4, 'Safely managed service' : 5})
dw_15v20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Service Type    20 non-null     object
#  2   Service Level   20 non-null     int64
#  3   Coverage        20 non-null     float64
#  4   Type            20 non-null     object
#  5   Region          20 non-null     object
#  6   Residence Type  20 non-null     object
#  7   Population      20 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.4+ KB

# %%
dw_15v20.head()
# Out:
#    Year    Service Type  Service Level   Coverage   Type Region  \
# 0  2015  Drinking water              3  26.161708  world  World
# 1  2015  Drinking water              3  11.075658  world  World
# 2  2015  Drinking water              2   5.392324  world  World
# 3  2015  Drinking water              2   1.640053  world  World
# 4  2015  Drinking water              5  52.836610  world  World
#
#   Residence Type    Population
# 0          rural  8.893554e+08
# 1          urban  4.408441e+08
# 2          rural  1.833096e+08
# 3          urban  6.527899e+07
# 4          rural  1.796157e+09

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read in the dataset
dw2015 = pd.read_csv('drinkingwater2015.csv')

# %%
dw2015.head()
# Out:
#   ISO3      Country Residence Type    Service Type  Year  Coverage  \
# 0  ABW        Aruba          total  Drinking water  2015  97.86903
# 1  ABW        Aruba          total  Drinking water  2015   0.00000
# 2  ABW        Aruba          total  Drinking water  2015   0.17104
# 3  ABW        Aruba          total  Drinking water  2015   1.95994
# 4  AFG  Afghanistan          total  Drinking water  2015  37.96357
#
#      Population    Service level
# 0  1.021156e+05   At least basic
# 1  0.000000e+00  Limited service
# 2  1.784618e+02    Surface water
# 3  2.044978e+03       Unimproved
# 4  1.306463e+07    Basic service

# %%
# group the data by year and service level, and count the number of countries in each group
dw2015_grouped = dw2015.groupby(['Year', 'Service level'])['Country'].count().reset_index()

# %%
# reshape the data using pivot
dw2015_pivot = dw2015_grouped.pivot(index='Year', columns='Service level', values='Country')

# %%
import pandas as pd
import matplotlib.pyplot as plt


# group the data by service level
service_level_counts = dw_15v20['Service level'].value_counts()

# create a pie chart of the service level counts
plt.pie(service_level_counts, labels=service_level_counts.index, autopct='%1.1f%%')
plt.title('World Water Service Levels')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Service level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [84], in <cell line: 6>()
#       2 import matplotlib.pyplot as plt
#       5 # group the data by service level
# ----> 6 service_level_counts = dw_15v20['Service level'].value_counts()
#       8 # create a pie chart of the service level counts
#       9 plt.pie(service_level_counts, labels=service_level_counts.index, autopct='%1.1f%%')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Service level'

# %%
# filter for Service level, Residence Type, Year, Coverage
#dw_15v20 = dw_15v20[['Service Level', 'Residence Type', 'Year', 'Coverage']]

# group by service level, residence type, and year and sum population
dw_15v20 = dw_15v20.groupby(['Service Level', 'Residence Type', 'Year']).sum().reset_index()

# pivot the data to create stacked bar chart
dw_15v20_pivot = dw_15v20.pivot(index='Service Level', columns='Location', values='Coverage')

# create stacked bar chart
sns.set_style('whitegrid')
ax = dw_15v20_pivot.plot(kind='bar', stacked=True, figsize=(8,6))
ax.set_title('Rural and Urban Drinking Water Service Levels, 2015 and 2020')
ax.set_xlabel('Service Level')
ax.set_ylabel('Coverage (%)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [83], in <cell line: 8>()
#       5 dw_15v20 = dw_15v20.groupby(['Service Level', 'Residence Type', 'Year']).sum().reset_index()
#       7 # pivot the data to create stacked bar chart
# ----> 8 dw_15v20_pivot = dw_15v20.pivot(index='Service Level', columns='Location', values='Coverage')
#      10 # create stacked bar chart
#      11 sns.set_style('whitegrid')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7876, in DataFrame.pivot(self, index, columns, values)
#    7871 @Substitution("")
#    7872 @Appender(_shared_docs["pivot"])
#    7873 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7874     from pandas.core.reshape.pivot import pivot
# -> 7876     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:508, in pivot(data, index, columns, values)
#     505 else:
#     506     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 508 data_columns = [data[col] for col in columns_listlike]
#     509 index_list.extend(data_columns)
#     510 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:508, in <listcomp>(.0)
#     505 else:
#     506     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 508 data_columns = [data[col] for col in columns_listlike]
#     509 index_list.extend(data_columns)
#     510 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Location'

# %%
world1520.head()
# Out:
#    Year    Service Type           Service Level   Coverage   Type Region  \
# 0  2015  Drinking water           Basic service  26.161708  world  World
# 1  2015  Drinking water           Basic service  11.075658  world  World
# 2  2015  Drinking water         Limited service   5.392324  world  World
# 3  2015  Drinking water         Limited service   1.640053  world  World
# 4  2015  Drinking water  Safely managed service  52.836610  world  World
#
#   Residence Type    Population
# 0          rural  8.893554e+08
# 1          urban  4.408441e+08
# 2          rural  1.833096e+08
# 3          urban  6.527899e+07
# 4          rural  1.796157e+09

# %% [markdown]
# ## Starting to examine Nigeria drinking water service level data

# %%
# Nigeria drinking water
nigeria_dw = sorted_dw.loc[sorted_dw['Country'] == 'Nigeria']
print(nigeria_dw.head(10))
# Out:
#       ISO3  Country Residence Type    Service Type  Year  Coverage  \
# 10607  NGA  Nigeria          total  Drinking water  2015   9.77293
# 13930  NGA  Nigeria          total  Drinking water  2015  14.73376
# 5541   NGA  Nigeria          total  Drinking water  2015   6.71355
# 2699   NGA  Nigeria          total  Drinking water  2015  48.91590
# 7798   NGA  Nigeria          total  Drinking water  2015  19.86386
# 10610  NGA  Nigeria          total  Drinking water  2016   8.90804
# 13933  NGA  Nigeria          total  Drinking water  2016  14.14314
# 5544   NGA  Nigeria          total  Drinking water  2016   6.40789
# 2702   NGA  Nigeria          total  Drinking water  2016  50.30609
# 7801   NGA  Nigeria          total  Drinking water  2016  20.23484
#
#          Population  Service level
# 10607  1.770244e+07              0
# 13930  2.668836e+07              1
# 5541   1.216076e+07              2
# 2699   8.860501e+07              3
# 7798   3.598089e+07              5
# 10610  1.656541e+07              0
# 13933  2.630061e+07              1
# 5544   1.191613e+07              2
# 2702   9.354934e+07              3
# 7801   3.762877e+07              5
